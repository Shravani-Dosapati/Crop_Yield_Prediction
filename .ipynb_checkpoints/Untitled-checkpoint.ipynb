# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split 
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
ade = pd.read_excel('Adverse Drug Event (ADE) Prediction and Analysis.xlsx')
ade.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Patient_ID     100000 non-null  int64
#  1   Drug           100000 non-null  object
#  2   Age            100000 non-null  int64
#  3   History        100000 non-null  object
#  4   Predicted_ADE  100000 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 3.8+ MB

# %%
pcos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Instructions to be followed :  12 non-null     float64
#  1   Unnamed: 1                     12 non-null     object
#  2   Unnamed: 2                     0 non-null      float64
#  3   Unnamed: 3                     8 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 772.0+ bytes

# %%
ade.head()
# Out:
#    Instructions to be followed :  \
# 0                            NaN
# 1                            1.0
# 2                            2.0
# 3                            3.0
# 4                            4.0
#
#                                           Unnamed: 1  Unnamed: 2 Unnamed: 3
# 0                                                NaN         NaN        NaN
# 1   Kindly ensure that the datas are converted to...         NaN        NaN
# 2    Please fill up the entire data set of a patient         NaN        NaN
# 3  Manipulated datas if any need to be highlighte...         NaN        NaN
# 4  For every Yes/No questions *** ,  Indicate Yes...         NaN        NaN
